# %% [markdown]
# <a href="https://colab.research.google.com/github/wily037/Ameyo-data-minds/blob/main/STUDENT_SCORES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
importimport pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data={'Names':['Wilfred', 'John', 'James','Nancy', 'Elizabeth', 'William', 'Joseph', 'Jabez','Leah', 'Millicent'],
'Sex':['Male', 'Male', 'Male', 'Female', 'Female', 'Male', 'Male', 'Male', 'Female', 'Female']
,'Age':[23,22,24,21,25,20,22,25,21,24]
,'County':['Busia','Kisumu','Kakamega','Kisii','Kercho', 'Nyeri', 'Mombasa', 'Nakuru','Meru','Nairobi']
, 'Scores':[78,60,89,56,67,40,64,78,80,73]}
df=pd.DataFrame(data)
display(df)
#1. Descriptive statistics/understanding the data.
df.head(8)
df.isnull().sum()
df.describe()
df.shape
df.dtypes
df['County'].unique()
df[df['Scores']>60]
df[(df['Scores'] > 50)& (df['Scores'] < 70)]
df[df['Scores']<60]
df[df['Names']=='Nancy']
df[df['Age']>22]
df[df['Sex']=='Male']
df[df['Sex']=='Female']
df.groupby('Sex')['Scores'].mean()
df.groupby('Sex').size()
df.groupby('County')['Scores'].mean()
df.groupby('Sex')['Scores'].sum()
df.groupby('Sex')['Age'].mean()
df.groupby('Sex')['Scores'].max()
df.groupby('Names')['Scores'].mean()
df.groupby('Sex')['Scores'].max()
df.groupby('Names')['Scores'].min()
df.nlargest(1, 'Scores')
df.nsmallest(1, 'Scores')
df.nlargest(3, 'Scores')
df.nsmallest(5, 'Scores')
df[df['Names']=='John']
df.nsmallest(5, 'Scores')
#the first 4 students
df.nlargest(6, 'Scores')
df.plot(x='Names',y='Scores', kind='bar')
plt.show()
df.columns
df['Age'].plot(kind='hist',bins=5)
plt.show()
sns.histplot(['Scores'],bins=5)
sns.histplot(['Age'],bins=10)
df.plot(x='Names',y='Age', kind='bar')
plt.show()
df.plot(x='Names',y='Scores', kind='line')
plt.show()
df.plot(x='Names',y='Age', kind='line')
plt.show()
df['Scores'].plot (kind='hist',bins=5)
# Out:
#        Names     Sex  Age    County  Scores
# 0    Wilfred    Male   23     Busia      78
# 1       John    Male   22    Kisumu      60
# 2      James    Male   24  Kakamega      89
# 3      Nancy  Female   21     Kisii      56
# 4  Elizabeth  Female   25    Kercho      67
# 5    William    Male   20     Nyeri      40
# 6     Joseph    Male   22   Mombasa      64
# 7      Jabez    Male   25    Nakuru      78
# 8       Leah  Female   21      Meru      80
# 9  Millicent  Female   24   Nairobi      73
# <Axes: ylabel='Frequency'>
